# %% [markdown]
# <a href="https://colab.research.google.com/github/lonehuntress/AeroSafe-AI/blob/main/colab/export_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib

model = joblib.load(
    "aerosafe_model.pkl"
)

# %%
print(type(model))
# Out:
# <class 'xgboost.sklearn.XGBClassifier'>
