# %% [markdown]
# <a href="https://colab.research.google.com/github/lonehuntress/AeroSafe-AI/blob/main/colab/model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = pd.read_csv("/content/drive/MyDrive/AeroSafeAI/X_train.csv")
X_test = pd.read_csv("/content/drive/MyDrive/AeroSafeAI/X_test.csv")

y_train = pd.read_csv("/content/drive/MyDrive/AeroSafeAI/y_train.csv")
y_test = pd.read_csv("/content/drive/MyDrive/AeroSafeAI/y_test.csv")

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)

# %%
model.fit(
    X_train,
    y_train.values.ravel()
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
predictions = model.predict(X_test)

# %%
import joblib
import os

os.makedirs("models", exist_ok=True)

joblib.dump(
    model,
    "models/aerosafe_model.pkl"
)

print("Modèle sauvegardé avec succès")
# Out:
# Modèle sauvegardé avec succès

# %%
from google.colab import files

files.download("/content/models/aerosafe_model.pkl")
